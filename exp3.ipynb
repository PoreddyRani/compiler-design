# %% [markdown]
# <a href="https://colab.research.google.com/github/PoreddyRani/compiler-design/blob/main/exp3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3a.Banking Transaction Log

# %%
s = input("enter a sentence:")
keywords = ["order", "cancel", "menu", "payment"]
if s in keywords:
    print("Keyword")
else:
    print("Not Keyword")
# Out:
# enter a sentence:order
# Keyword

# %% [markdown]
# 3b.School Mark sheet Formula

# %%
s = input("enter a sentence:")
keywords = ["issue", "return", "search", "book"]
if s in keywords:
    print("Keyword")
else:
    print("Not Keyword")
# Out:
# enter a sentence:issue
# Keyword
