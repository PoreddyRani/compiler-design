# %% [markdown]
# <a href="https://colab.research.google.com/github/PoreddyRani/compiler-design/blob/main/exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2a.E-commerce Discount Rule

# %%
exp = input("enter:")
count = 0
for i in exp:
    if i == "(":
        count += 1
    elif i == ")":
        count -= 1
if count == 0:
    print("Valid")
else:
    print("Invalid")
# Out:
# enter:(a+b)
# Valid

# %% [markdown]
# 2b.Car Parking Ticket Format

# %%
exp = input("enter:")
count = 0
for i in exp:
    if i == "(":
        count += 1
    elif i == ")":
        count -= 1
if count == 0:
    print("Valid")
else:
    print("Invalid")
# Out:
# enter:(a*b
# Invalid
